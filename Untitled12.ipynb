# %% [markdown]
# <a href="https://colab.research.google.com/github/Livia711/livia/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Dados de exemplo
meses = ['Janeiro', 'Fevereiro','Março', 'Abril', 'Maio']
vendas = [120, 90, 150, 80, 200]

# Criar um gráfico de barras
plt.bar(meses, vendas, color = 'red')

# Adicionar rótulos aos eixos
plt.xlabel('Mês')
plt.ylabel('Vendas')

# Adicionar um título ao gráfico
plt.title('Vendas Mensais')

# Exibir o gráfico
plt.show()
