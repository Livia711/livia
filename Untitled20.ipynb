# %% [markdown]
# <a href="https://colab.research.google.com/github/Livia711/livia/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3

# Conectar ao banco de dados
conexao = sqlite3.connect('dados_vendas.db')
# Criar um crusor
cursor = conexao.cursor()

# Criar a tabela Produtos
create_table = """
    CREATE TABLE IF NOT EXISTS Produtos (
        id INTEGER PRIMARY KEY,
        nome TEXT,
        preco REAL,
        estoque INTEGER
);
"""
cursor.execute(create_table) # Executar a criação da tabela Produtos

# Criar a tabela vendas1
cursor.execute('''
CREATE TABLE IF NOT EXISTS vendas1 (
    data_venda TEXT,
    produto TEXT,
    categoria TEXT,
    valor_venda REAL
);
''')

# Inserir dados na tabela vendas1
cursor.execute('''
INSERT INTO vendas1 (data_venda, produto, categoria, valor_venda) VALUES
('2023-01-01', 'Produto A', 'Eletrônicos', 1500.00),
('2023-01-05', 'Produto B', 'Roupas', 350.00),
('2023-02-10', 'Produto C', 'Eletrônicos', 1200.00),
('2023-03-15', 'Produto D', 'Livros', 200.00),
('2023-03-20', 'Produto E', 'Eletrônicos', 800.00),
('2023-04-02', 'Produto F', 'Roupas', 400.00),
('2023-05-05', 'Produto G', 'Livros', 150.00),
('2023-06-10', 'Produto H', 'Eletrônicos', 1000.00),
('2023-07-20', 'Produto I', 'Roupas', 600.00),
('2023-08-25', 'Produto J', 'Eletrônicos', 700.00),
('2023-09-30', 'Produto K', 'Livros', 300.00),
('2023-10-05', 'Produto L', 'Roupas', 450.00),
('2023-11-15', 'Produto M', 'Eletrônicos', 900.00),
('2023-12-20', 'Produto N', 'Livros', 250.00);
''')

# Commit as mudanças e fechar a conexão
conexao.commit()
conexao.close()

# Conectando ao banco de dados
conn = sqlite3.connect('dados_vendas.db')

# Changed 'dados_de_vendas' to 'vendas1'
df = pd.read_sql_query("SELECT * FROM vendas1", conn)
print(df)
# Out:
#      data_venda    produto    categoria  valor_venda
# 0    2023-01-01  Produto A  Eletrônicos       1500.0
# 1    2023-01-05  Produto B       Roupas        350.0
# 2    2023-02-10  Produto C  Eletrônicos       1200.0
# 3    2023-03-15  Produto D       Livros        200.0
# 4    2023-03-20  Produto E  Eletrônicos        800.0
# ..          ...        ...          ...          ...
# 121  2023-08-25  Produto J  Eletrônicos        700.0
# 122  2023-09-30  Produto K       Livros        300.0
# 123  2023-10-05  Produto L       Roupas        450.0
# 124  2023-11-15  Produto M  Eletrônicos        900.0
# 125  2023-12-20  Produto N       Livros        250.0
#
# [126 rows x 4 columns]

# %%
# Calculando a coluna 'preço do item' using 'valor_venda' instead of 'receita total'
# Assuming 'quantidade de itens comprados' should be 1 for this example
df['preço do item'] = df['valor_venda'] / 1

# Selecionando preço do intem acima de 50 reais
itens_acima_de_500 = df[df['preço do item'] > 500]
print(itens_acima_de_500)
# Out:
#      data_venda    produto    categoria  valor_venda  preço do item
# 112  2023-01-01  Produto A  Eletrônicos       1500.0         1500.0
# 114  2023-02-10  Produto C  Eletrônicos       1200.0         1200.0
# 116  2023-03-20  Produto E  Eletrônicos        800.0          800.0
# 119  2023-06-10  Produto H  Eletrônicos       1000.0         1000.0
# 120  2023-07-20  Produto I       Roupas        600.0          600.0
# 121  2023-08-25  Produto J  Eletrônicos        700.0          700.0
# 124  2023-11-15  Produto M  Eletrônicos        900.0          900.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Exemplo de visualização de vendas ao longo do tempo
plt.figure(figsize=(10, 7))
# Changed 'data' to 'data_venda'
sns.barplot(x='data_venda', y='valor_venda', data=df)
plt.title('Vendas ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Valor da Venda')
plt.show()
