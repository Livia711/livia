# %% [markdown]
# <a href="https://colab.research.google.com/github/Livia711/livia/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3

# Conectar ao banco de dados
conexao = sqlite3.connect('dados_vendas.db')
# Criar um crusor
cursor = conexao.cursor()

# Criar a tabela Produtos
create_table = """
    CREATE TABLE IF NOT EXISTS Produtos (
        id INTEGER PRIMARY KEY,
        nome TEXT,
        preco REAL,
        estoque INTEGER
);
"""
cursor.execute(create_table) # Executar a criação da tabela Produtos

# Criar a tabela vendas1
cursor.execute('''
CREATE TABLE IF NOT EXISTS vendas1 (
    data_venda TEXT,
    produto TEXT,
    categoria TEXT,
    valor_venda REAL
);
''')

# Inserir dados na tabela vendas1
cursor.execute('''
INSERT INTO vendas1 (data_venda, produto, categoria, valor_venda) VALUES
('2023-01-01', 'Produto A', 'Eletrônicos', 1500.00),
('2023-01-05', 'Produto B', 'Roupas', 350.00),
('2023-02-10', 'Produto C', 'Eletrônicos', 1200.00),
('2023-03-15', 'Produto D', 'Livros', 200.00),
('2023-03-20', 'Produto E', 'Eletrônicos', 800.00),
('2023-04-02', 'Produto F', 'Roupas', 400.00),
('2023-05-05', 'Produto G', 'Livros', 150.00),
('2023-06-10', 'Produto H', 'Eletrônicos', 1000.00),
('2023-07-20', 'Produto I', 'Roupas', 600.00),
('2023-08-25', 'Produto J', 'Eletrônicos', 700.00),
('2023-09-30', 'Produto K', 'Livros', 300.00),
('2023-10-05', 'Produto L', 'Roupas', 450.00),
('2023-11-15', 'Produto M', 'Eletrônicos', 900.00),
('2023-12-20', 'Produto N', 'Livros', 250.00);
''')

# Commit as mudanças e fechar a conexão
conexao.commit()
conexao.close()

# Conectando ao banco de dados
conn = sqlite3.connect('dados_vendas.db')

# Changed 'dados_de_vendas' to 'vendas1'
df = pd.read_sql_query("SELECT * FROM vendas1", conn)
print(df)
# Out:
#     data_venda    produto    categoria  valor_venda
# 0   2023-01-01  Produto A  Eletrônicos       1500.0
# 1   2023-01-05  Produto B       Roupas        350.0
# 2   2023-02-10  Produto C  Eletrônicos       1200.0
# 3   2023-03-15  Produto D       Livros        200.0
# 4   2023-03-20  Produto E  Eletrônicos        800.0
# ..         ...        ...          ...          ...
# 65  2023-08-25  Produto J  Eletrônicos        700.0
# 66  2023-09-30  Produto K       Livros        300.0
# 67  2023-10-05  Produto L       Roupas        450.0
# 68  2023-11-15  Produto M  Eletrônicos        900.0
# 69  2023-12-20  Produto N       Livros        250.0
#
# [70 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Exemplo de visualização de vendas ao longo do tempo
plt.figure(figsize=(10, 11))
# Removed the invalid 'z' argument. If you want to represent 'Produto', consider using 'hue'
sns.barplot(x='data_venda', y='valor_venda', hue="produto", data=df)
plt.title('Vendas ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Valor da Venda')
plt.xticks(rotation=45)
plt.show()
